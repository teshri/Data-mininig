# %% [markdown]
# # Run following algorithms on 2 real datasets and use appropriate evaluation measures to compute correctness of obtained patterns:

# %% [markdown]
# # Q4. Run Apriori algorithm to find frequent itemsets and association rules
# ## 4.1 Use minimum support as 50% and minimum confidence as 75%
# ## 4.2 Use minimum support as 60% and minimum confidence as 60 %

# %%
# !pip install mlxtend

# %%
import numpy as np
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

# %%
df = pd.read_excel('Online Retail.xlsx')
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %%
data1 = df[df.Country=="France"]

# %%
# Load the data (replace with your own dataset)
data = data1
# data = pd.read_csv('Online_Retail.csv')
# Clean the data
data['Description'] = data['Description'].str.strip()
data.dropna(axis=0, subset=['InvoiceNo'], inplace=True)
data['InvoiceNo'] = data['InvoiceNo'].astype('str')
data = data[~data['InvoiceNo'].str.contains('C')]

# Split data by region (e.g., France, UK, etc.)
basket = (data
                 .groupby(['InvoiceNo', 'Description'])['Quantity']
                 .sum().unstack().reset_index().fillna(0)
                 .set_index('InvoiceNo'))

# Hot encode the data
def hot_encode(x):
    return 0 if x <= 0 else 1

basket_encoded = basket.applymap(hot_encode)

# Build the model
frq_items = apriori(basket_encoded, min_support=0.05, use_colnames=True)
rules = association_rules(frq_items, metric="lift", min_threshold=1)
rules = rules.sort_values(['confidence', 'lift'], ascending=[False, False])
print(rules.head())
# Out:
# C:\Users\shadj\AppData\Local\Temp\ipykernel_1864\2801206632.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Description'] = data['Description'].str.strip()
# C:\Users\shadj\AppData\Local\Temp\ipykernel_1864\2801206632.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(axis=0, subset=['InvoiceNo'], inplace=True)
# C:\Users\shadj\AppData\Local\Temp\ipykernel_1864\2801206632.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['InvoiceNo'] = data['InvoiceNo'].astype('str')
#                                            antecedents  \
# 45                        (JUMBO BAG WOODLAND ANIMALS)
# 259  (RED TOADSTOOL LED NIGHT LIGHT, PLASTERS IN TI...
# 270  (RED TOADSTOOL LED NIGHT LIGHT, PLASTERS IN TI...
# 300  (SET/6 RED SPOTTY PAPER CUPS, SET/20 RED RETRO...
# 302  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
#
#                          consequents  antecedent support  consequent support  \
# 45                         (POSTAGE)            0.076531            0.765306
# 259                        (POSTAGE)            0.051020            0.765306
# 270                        (POSTAGE)            0.053571            0.765306
# 300  (SET/6 RED SPOTTY PAPER PLATES)            0.102041            0.127551
# 302    (SET/6 RED SPOTTY PAPER CUPS)            0.102041            0.137755
#
#       support  confidence      lift  leverage  conviction  zhangs_metric
# 45   0.076531       1.000  1.306667  0.017961         inf       0.254144
# 259  0.051020       1.000  1.306667  0.011974         inf       0.247312
# 270  0.053571       1.000  1.306667  0.012573         inf       0.247978
# 300  0.099490       0.975  7.644000  0.086474   34.897959       0.967949
# 302  0.099490       0.975  7.077778  0.085433   34.489796       0.956294
# C:\Users\shadj\Python\Python310\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:109: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
assc_rules = rules.loc[:,["antecedents","consequents","support","confidence"]]
assc_rules
# Out:
#                                            antecedents  \
# 45                        (JUMBO BAG WOODLAND ANIMALS)
# 259  (RED TOADSTOOL LED NIGHT LIGHT, PLASTERS IN TI...
# 270  (RED TOADSTOOL LED NIGHT LIGHT, PLASTERS IN TI...
# 300  (SET/6 RED SPOTTY PAPER CUPS, SET/20 RED RETRO...
# 302  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# ..                                                 ...
# 36                                           (POSTAGE)
# 26                                           (POSTAGE)
# 97                                           (POSTAGE)
# 226                                          (POSTAGE)
# 214                                          (POSTAGE)
#
#                                            consequents   support  confidence
# 45                                           (POSTAGE)  0.076531    1.000000
# 259                                          (POSTAGE)  0.051020    1.000000
# 270                                          (POSTAGE)  0.053571    1.000000
# 300                    (SET/6 RED SPOTTY PAPER PLATES)  0.099490    0.975000
# 302                      (SET/6 RED SPOTTY PAPER CUPS)  0.099490    0.975000
# ..                                                 ...       ...         ...
# 36                            (JAM MAKING SET PRINTED)  0.051020    0.066667
# 26                   (CIRCUS PARADE CHILDRENS EGG CUP)  0.051020    0.066667
# 97                                     (PARTY BUNTING)  0.051020    0.066667
# 226      (LUNCH BAG RED RETROSPOT, LUNCH BAG WOODLAND)  0.051020    0.066667
# 214  (LUNCH BAG SPACEBOY DESIGN, LUNCH BAG APPLE DE...  0.051020    0.066667
#
# [348 rows x 4 columns]

# %% [markdown]
# ## 4.1 Use minimum support as 50% and minimum confidence as 75%

# %%
#Selecting all the rules which have a minimun supprt of 50% and a minimum confidence of 75%
temp = assc_rules[assc_rules.support>0.05]
rules1 = temp[assc_rules.confidence>0.75]
rules1
# Out:
#                                            antecedents  \
# 45                        (JUMBO BAG WOODLAND ANIMALS)
# 259  (RED TOADSTOOL LED NIGHT LIGHT, PLASTERS IN TI...
# 270  (RED TOADSTOOL LED NIGHT LIGHT, PLASTERS IN TI...
# 300  (SET/6 RED SPOTTY PAPER CUPS, SET/20 RED RETRO...
# 302  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# ..                                                 ...
# 342           (POSTAGE, SET/6 RED SPOTTY PAPER PLATES)
# 113                         (PLASTERS IN TIN SPACEBOY)
# 310  (ALARM CLOCK BAKELIKE RED, ALARM CLOCK BAKELIK...
# 314  (ALARM CLOCK BAKELIKE PINK, ALARM CLOCK BAKELI...
# 191                         (ALARM CLOCK BAKELIKE RED)
#
#                                            consequents   support  confidence
# 45                                           (POSTAGE)  0.076531    1.000000
# 259                                          (POSTAGE)  0.051020    1.000000
# 270                                          (POSTAGE)  0.053571    1.000000
# 300                    (SET/6 RED SPOTTY PAPER PLATES)  0.099490    0.975000
# 302                      (SET/6 RED SPOTTY PAPER CUPS)  0.099490    0.975000
# ..                                                 ...       ...         ...
# 342  (SET/6 RED SPOTTY PAPER CUPS, SET/20 RED RETRO...  0.081633    0.761905
# 113                 (PLASTERS IN TIN WOODLAND ANIMALS)  0.104592    0.759259
# 310              (POSTAGE, ALARM CLOCK BAKELIKE GREEN)  0.056122    0.758621
# 314                (ALARM CLOCK BAKELIKE RED, POSTAGE)  0.056122    0.758621
# 191              (POSTAGE, ALARM CLOCK BAKELIKE GREEN)  0.071429    0.756757
#
# [118 rows x 4 columns]

# %% [markdown]
# ##  4.2 Use minimum support as 60% and minimum confidence as 60 %

# %%
#Selecting all the rules which have a minimun supprt of 60% and a minimum confidence of 60%
temp = assc_rules[assc_rules.support>0.06]
rules2 = temp[assc_rules.confidence>0.6]
rules2
# Out:
# C:\Users\shadj\AppData\Local\Temp\ipykernel_1864\2960442021.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   rules2 = temp[assc_rules.confidence>0.6]
#                                            antecedents  \
# 45                        (JUMBO BAG WOODLAND ANIMALS)
# 300  (SET/6 RED SPOTTY PAPER CUPS, SET/20 RED RETRO...
# 302  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 334  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 337  (SET/20 RED RETROSPOT PAPER NAPKINS, POSTAGE, ...
# ..                                                 ...
# 285                      (SET/6 RED SPOTTY PAPER CUPS)
# 265        (PLASTERS IN TIN WOODLAND ANIMALS, POSTAGE)
# 268                         (PLASTERS IN TIN SPACEBOY)
# 254        (PLASTERS IN TIN WOODLAND ANIMALS, POSTAGE)
# 102                    (PLASTERS IN TIN CIRCUS PARADE)
#
#                                        consequents   support  confidence
# 45                                       (POSTAGE)  0.076531    1.000000
# 300                (SET/6 RED SPOTTY PAPER PLATES)  0.099490    0.975000
# 302                  (SET/6 RED SPOTTY PAPER CUPS)  0.099490    0.975000
# 334                (SET/6 RED SPOTTY PAPER PLATES)  0.081633    0.969697
# 337                  (SET/6 RED SPOTTY PAPER CUPS)  0.081633    0.969697
# ..                                             ...       ...         ...
# 285  (SET/20 RED RETROSPOT PAPER NAPKINS, POSTAGE)  0.084184    0.611111
# 265                     (PLASTERS IN TIN SPACEBOY)  0.084184    0.611111
# 268    (PLASTERS IN TIN WOODLAND ANIMALS, POSTAGE)  0.084184    0.611111
# 254                (PLASTERS IN TIN CIRCUS PARADE)  0.084184    0.611111
# 102             (PLASTERS IN TIN WOODLAND ANIMALS)  0.102041    0.606061
#
# [122 rows x 4 columns]

# %%
data2 = df[df.Country=="Spain"]

# %%
# Load the data (replace with your own dataset)
data = data2
# data = pd.read_csv('Online_Retail.csv')
# Clean the data
data['Description'] = data['Description'].str.strip()
data.dropna(axis=0, subset=['InvoiceNo'], inplace=True)
data['InvoiceNo'] = data['InvoiceNo'].astype('str')
data = data[~data['InvoiceNo'].str.contains('C')]

# Split data by region (e.g., France, UK, etc.)
basket = (data
                 .groupby(['InvoiceNo', 'Description'])['Quantity']
                 .sum().unstack().reset_index().fillna(0)
                 .set_index('InvoiceNo'))

# Hot encode the data
def hot_encode(x):
    return 0 if x <= 0 else 1

basket_encoded = basket.applymap(hot_encode)

# Build the model
frq_items = apriori(basket_encoded, min_support=0.05, use_colnames=True)
rules = association_rules(frq_items, metric="lift", min_threshold=1)
rules = rules.sort_values(['confidence', 'lift'], ascending=[False, False])
print(rules.head())
# Out:
#                                            antecedents  \
# 240     (LUNCH BAG CARS BLUE, LUNCH BAG PINK POLKADOT)
# 245                          (LUNCH BAG  BLACK SKULL.)
# 64                    (PINK REGENCY TEACUP AND SAUCER)
# 85                           (LUNCH BAG  BLACK SKULL.)
# 235  (PINK REGENCY TEACUP AND SAUCER, ROSES REGENCY...
#
#                                         consequents  antecedent support  \
# 240                       (LUNCH BAG  BLACK SKULL.)            0.055556
# 245  (LUNCH BAG CARS BLUE, LUNCH BAG PINK POLKADOT)            0.055556
# 64                (GREEN REGENCY TEACUP AND SAUCER)            0.055556
# 85                            (LUNCH BAG CARS BLUE)            0.055556
# 235               (GREEN REGENCY TEACUP AND SAUCER)            0.055556
#
#      consequent support   support  confidence  lift  leverage  conviction  \
# 240            0.055556  0.055556         1.0  18.0  0.052469         inf
# 245            0.055556  0.055556         1.0  18.0  0.052469         inf
# 64             0.066667  0.055556         1.0  15.0  0.051852         inf
# 85             0.066667  0.055556         1.0  15.0  0.051852         inf
# 235            0.066667  0.055556         1.0  15.0  0.051852         inf
#
#      zhangs_metric
# 240       1.000000
# 245       1.000000
# 64        0.988235
# 85        0.988235
# 235       0.988235
# C:\Users\shadj\AppData\Local\Temp\ipykernel_1864\2060633128.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Description'] = data['Description'].str.strip()
# C:\Users\shadj\AppData\Local\Temp\ipykernel_1864\2060633128.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(axis=0, subset=['InvoiceNo'], inplace=True)
# C:\Users\shadj\AppData\Local\Temp\ipykernel_1864\2060633128.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['InvoiceNo'] = data['InvoiceNo'].astype('str')
# C:\Users\shadj\Python\Python310\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:109: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
assc_rules = rules.loc[:,["antecedents","consequents","support","confidence"]]
assc_rules
# Out:
#                                            antecedents  \
# 240     (LUNCH BAG CARS BLUE, LUNCH BAG PINK POLKADOT)
# 245                          (LUNCH BAG  BLACK SKULL.)
# 64                    (PINK REGENCY TEACUP AND SAUCER)
# 85                           (LUNCH BAG  BLACK SKULL.)
# 235  (PINK REGENCY TEACUP AND SAUCER, ROSES REGENCY...
# ..                                                 ...
# 141                                          (POSTAGE)
# 143                                          (POSTAGE)
# 214                                          (POSTAGE)
# 263                                          (POSTAGE)
# 103                                          (POSTAGE)
#
#                                            consequents   support  confidence
# 240                          (LUNCH BAG  BLACK SKULL.)  0.055556    1.000000
# 245     (LUNCH BAG CARS BLUE, LUNCH BAG PINK POLKADOT)  0.055556    1.000000
# 64                   (GREEN REGENCY TEACUP AND SAUCER)  0.055556    1.000000
# 85                               (LUNCH BAG CARS BLUE)  0.055556    1.000000
# 235                  (GREEN REGENCY TEACUP AND SAUCER)  0.055556    1.000000
# ..                                                 ...       ...         ...
# 141                           (TEA TIME KITCHEN APRON)  0.055556    0.080645
# 143                (WORLD WAR 2 GLIDERS ASSTD DESIGNS)  0.055556    0.080645
# 214  (ASSORTED COLOUR BIRD ORNAMENT, PLASTERS IN TI...  0.055556    0.080645
# 263  (PLASTERS IN TIN CIRCUS PARADE, PLASTERS IN TI...  0.055556    0.080645
# 103                          (PAPER BUNTING RETROSPOT)  0.055556    0.080645
#
# [304 rows x 4 columns]

# %% [markdown]
# ## 4.1 Use minimum support as 50% and minimum confidence as 75%

# %%
#Selecting all the rules which have a minimun supprt of 50% and a minimum confidence of 75%
temp = assc_rules[assc_rules.support>0.05]
rules2 = temp[assc_rules.confidence>0.75]
rules2
# Out:
#                                            antecedents  \
# 240     (LUNCH BAG CARS BLUE, LUNCH BAG PINK POLKADOT)
# 245                          (LUNCH BAG  BLACK SKULL.)
# 64                    (PINK REGENCY TEACUP AND SAUCER)
# 85                           (LUNCH BAG  BLACK SKULL.)
# 235  (PINK REGENCY TEACUP AND SAUCER, ROSES REGENCY...
# ..                                                 ...
# 258  (PLASTERS IN TIN CIRCUS PARADE, PLASTERS IN TI...
# 169           (ASSORTED COLOUR BIRD ORNAMENT, POSTAGE)
# 110                           (PLASTERS IN TIN SKULLS)
# 132               (SET OF 72 RETROSPOT PAPER  DOILIES)
# 122                         (REGENCY CAKESTAND 3 TIER)
#
#                                         consequents   support  confidence
# 240                       (LUNCH BAG  BLACK SKULL.)  0.055556    1.000000
# 245  (LUNCH BAG CARS BLUE, LUNCH BAG PINK POLKADOT)  0.055556    1.000000
# 64                (GREEN REGENCY TEACUP AND SAUCER)  0.055556    1.000000
# 85                            (LUNCH BAG CARS BLUE)  0.055556    1.000000
# 235               (GREEN REGENCY TEACUP AND SAUCER)  0.055556    1.000000
# ..                                              ...       ...         ...
# 258                                       (POSTAGE)  0.055556    0.833333
# 169                        (6 RIBBONS RUSTIC CHARM)  0.100000    0.818182
# 110                                       (POSTAGE)  0.088889    0.800000
# 132                                       (POSTAGE)  0.088889    0.800000
# 122                                       (POSTAGE)  0.188889    0.772727
#
# [104 rows x 4 columns]

# %% [markdown]
# ##  4.2 Use minimum support as 60% and minimum confidence as 60 %

# %%
temp = assc_rules[assc_rules.support>0.05]
rules4 = temp[assc_rules.confidence>0.60]
rules4
# Out:
#                                            antecedents  \
# 240     (LUNCH BAG CARS BLUE, LUNCH BAG PINK POLKADOT)
# 245                          (LUNCH BAG  BLACK SKULL.)
# 64                    (PINK REGENCY TEACUP AND SAUCER)
# 85                           (LUNCH BAG  BLACK SKULL.)
# 235  (PINK REGENCY TEACUP AND SAUCER, ROSES REGENCY...
# ..                                                 ...
# 13                  (PLASTERS IN TIN WOODLAND ANIMALS)
# 17                          (RED RETROSPOT CAKE STAND)
# 146                         (RED RETROSPOT CAKE STAND)
# 172                           (6 RIBBONS RUSTIC CHARM)
# 3                             (6 RIBBONS RUSTIC CHARM)
#
#                                         consequents   support  confidence
# 240                       (LUNCH BAG  BLACK SKULL.)  0.055556       1.000
# 245  (LUNCH BAG CARS BLUE, LUNCH BAG PINK POLKADOT)  0.055556       1.000
# 64                (GREEN REGENCY TEACUP AND SAUCER)  0.055556       1.000
# 85                            (LUNCH BAG CARS BLUE)  0.055556       1.000
# 235               (GREEN REGENCY TEACUP AND SAUCER)  0.055556       1.000
# ..                                              ...       ...         ...
# 13                         (6 RIBBONS RUSTIC CHARM)  0.055556       0.625
# 17                         (6 RIBBONS RUSTIC CHARM)  0.055556       0.625
# 146                      (REGENCY CAKESTAND 3 TIER)  0.055556       0.625
# 172        (ASSORTED COLOUR BIRD ORNAMENT, POSTAGE)  0.100000       0.600
# 3                   (ASSORTED COLOUR BIRD ORNAMENT)  0.100000       0.600
#
# [140 rows x 4 columns]
